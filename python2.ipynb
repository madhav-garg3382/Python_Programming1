# %% [markdown]
# ## Chapter1

# %%
a =2
b =3
print(a*b)
# Out:
# 6

# %%
a = 30
b = 20
print("What is the product of a and b")
print(a*b)

# %% [markdown]
# ### Dynamic Types in Python

# %%
a=30

# %%
a ="Vibhu"

# %%
a= 20
print(type(a))
a = 20/100
print(type(a))
a = "Text"
print(type(a))
