# %%
faculty_names = ["Dr. Alice Smith", "Prof. Bob Johnson", "Dr. Carol Williams", "Prof. David Brown"]

# %%
for each in faculty_names:
    if each.startswith("Dr."):
        print(each)
# Out:
# Dr. Alice Smith
# Dr. Carol Williams

# %%
type(True)
# Out:
# bool

# %%
type(True+True)
# Out:
# int

# %%
type(float(True))
# Out:
# float

# %%
bool(249546)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(int("0"))
# Out:
# False

# %%
bool(int)
# Out:
# True

# %%
4/4
# Out:
# 1.0

# %%
v = 12873
copy_of_v = 12873
while copy_of_v > 0:
    print(copy_of_v % 10)
    copy_of_v = copy_of_v // 10
# Out:
# 3
# 7
# 8
# 2
# 1
